# %% [markdown]
# # Lab EM3 EM Data Collection
#
# Due: Noon 1/31/3035
#
# Objectives:
# 1. Learn to collect FDEM data.
# 2. Take detailed notes!
# 3. Make georeferenced plots of the recorded data

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Tasks
# 1. Survey Kafadar using 3 different FDEM equipments (Friday)
# 2. Investigate the sensistivities of the different equipment with depth (Monday)

# %% [markdown]
# ## Instrumentation

# %% [markdown]
# ### EM31

# %% [markdown]
# ### EM34

# %% [markdown]
# ### GEM2
